# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('practice_day15.csv')
df.head()
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 3       E101        Alice  25.0  50000.0   1200      85      90      88
# 4       E104        David  45.0  80000.0   2500      88      85      89

# %% [markdown]
# 1. Add New Column and Save File
# You have a DataFrame with column Price.
#  Create a new column Discounted_Price with (10% discounted price).
#  Save the modified DataFrame as discounted_products.csv.

# %%
df.head()
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 3       E101        Alice  25.0  50000.0   1200      85      90      88
# 4       E104        David  45.0  80000.0   2500      88      85      89

# %%
df['Discounted_Price']=df['Price']*0.90
df.head()
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 3       E101        Alice  25.0  50000.0   1200      85      90      88
# 4       E104        David  45.0  80000.0   2500      88      85      89
#
#    Discounted_Price
# 0            1080.0
# 1            1350.0
# 2             990.0
# 3            1080.0
# 4            2250.0

# %%
# df.to_csv("discounted_products.csv", index=False)
df.to_csv('discounted_products.csv', index=False)

# %% [markdown]
# 2. Check Duplicates and Remove Them
# Column: EmployeeID
#  Tasks:
# Count duplicate entries
# Remove duplicates
# Display cleaned DataFrame

# %%
df
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank   NaN  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80
#
#     Discounted_Price
# 0             1080.0
# 1             1350.0
# 2              990.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.drop_duplicates(inplace=True)
df = df.copy()
df
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 4       E104        David  45.0  80000.0   2500      88      85      89
# 5       E105          Eve  29.0  58000.0   1300      76      79      81
# 6       E106        Frank   NaN  75000.0   2200      90      91      92
# 7       E107        Grace  34.0      NaN   1900      81      83      80
# 8       E108        Heidi  38.0      NaN   1800      84      86      88
# 9       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Discounted_Price
# 0            1080.0
# 1            1350.0
# 2             990.0
# 4            2250.0
# 5            1170.0
# 6            1980.0
# 7            1710.0
# 8            1620.0
# 9            1260.0

# %% [markdown]
# 3. Handle Missing Values
# Columns: Age, Salary
#  Tasks:
# Count missing values
# Fill missing Age with mean age
# Drop rows where Salary is missing

# %%
df
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 4       E104        David  45.0  80000.0   2500      88      85      89
# 5       E105          Eve  29.0  58000.0   1300      76      79      81
# 6       E106        Frank   NaN  75000.0   2200      90      91      92
# 7       E107        Grace  34.0      NaN   1900      81      83      80
# 8       E108        Heidi  38.0      NaN   1800      84      86      88
# 9       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Discounted_Price
# 0            1080.0
# 1            1350.0
# 2             990.0
# 4            2250.0
# 5            1170.0
# 6            1980.0
# 7            1710.0
# 8            1620.0
# 9            1260.0

# %%
df[["Age", "Salary"]].isnull().sum()
# Out:
# Age       1
# Salary    2
# dtype: int64

# %%
# df['Age']=df["Age"].fillna(df["Age"].mean())

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df
# Out:
#   EmployeeID EmployeeName     Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.000  50000.0   1200      85      90      88
# 1       E102          Bob  30.000  60000.0   1500      78      82      80
# 2       E103      Charlie  22.000  52000.0   1100      92      95      90
# 4       E104        David  45.000  80000.0   2500      88      85      89
# 5       E105          Eve  29.000  58000.0   1300      76      79      81
# 6       E106        Frank  31.125  75000.0   2200      90      91      92
# 7       E107        Grace  34.000      NaN   1900      81      83      80
# 8       E108        Heidi  38.000      NaN   1800      84      86      88
# 9       E109         Ivan  26.000  53000.0   1400      95      92      94
#
#    Discounted_Price
# 0            1080.0
# 1            1350.0
# 2             990.0
# 4            2250.0
# 5            1170.0
# 6            1980.0
# 7            1710.0
# 8            1620.0
# 9            1260.0

# %%
df = df.dropna(subset=["Salary"])

# %%
df
# Out:
#   EmployeeID EmployeeName     Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.000  50000.0   1200      85      90      88
# 1       E102          Bob  30.000  60000.0   1500      78      82      80
# 2       E103      Charlie  22.000  52000.0   1100      92      95      90
# 4       E104        David  45.000  80000.0   2500      88      85      89
# 5       E105          Eve  29.000  58000.0   1300      76      79      81
# 6       E106        Frank  31.125  75000.0   2200      90      91      92
# 9       E109         Ivan  26.000  53000.0   1400      95      92      94
#
#    Discounted_Price
# 0            1080.0
# 1            1350.0
# 2             990.0
# 4            2250.0
# 5            1170.0
# 6            1980.0
# 9            1260.0

# %% [markdown]
# 4. Apply Statistical Functions
# Columns: Marks1, Marks2, Marks3
#  Tasks:
# Calculate mean, max for each subject
# Compute total marks per student
# Find standard deviation of total marks

# %%
df[['Marks1','Marks2','Marks3']].sum(axis=0)
# Out:
# Marks1    604
# Marks2    614
# Marks3    614
# dtype: int64

# %%
df[['Marks1','Marks2','Marks3']].max(axis=0)
# Out:
# Marks1    95
# Marks2    95
# Marks3    94
# dtype: int64

# %%
df['TotalMarks']=df[['Marks1','Marks2','Marks3']].sum(axis=1)
df=df.copy()
df
# Out:
# C:\Users\Prothoma\AppData\Local\Temp\ipykernel_9352\3383299021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalMarks']=df[['Marks1','Marks2','Marks3']].sum(axis=1)
#   EmployeeID EmployeeName     Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.000  50000.0   1200      85      90      88
# 1       E102          Bob  30.000  60000.0   1500      78      82      80
# 2       E103      Charlie  22.000  52000.0   1100      92      95      90
# 4       E104        David  45.000  80000.0   2500      88      85      89
# 5       E105          Eve  29.000  58000.0   1300      76      79      81
# 6       E106        Frank  31.125  75000.0   2200      90      91      92
# ...

# %% [markdown]
# 5. Histogram, Bar, Scatter, Pie
# Create:
# Histogram of Age
# Scatter plot (Age vs Salary)
# Scatter plot ( Price vs Discounted Price)

# %%
import matplotlib.pyplot as plt 
import seaborn as sns  
import plotly.express as px

# %%
# sns.histplot(data=df,x='Age')
plt.xlabel('Age')
plt.hist(df['Age'])
# Out:
# (array([1., 2., 0., 3., 0., 0., 0., 0., 0., 1.]),
#  array([22. , 24.3, 26.6, 28.9, 31.2, 33.5, 35.8, 38.1, 40.4, 42.7, 45. ]),
#  <BarContainer object of 10 artists>)

# %%
# sns.scatterplot(data=df,x='Age',y='Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.scatter(df['Age'],df['Salary'])

# %%
#Scatter plot ( Price vs Discounted Price) 
# sns.scatterplot(data=df,x='Price',y='Discounted_Price')
plt.xlabel('Price')
plt.ylabel('Discounted_Price')
plt.scatter(df['Price'],df['Discounted_Price'])

# %% [markdown]
# 6. Load the dataset from the URL into a pandas DataFrame.
# Create a scatter plot with Study_Hours on the X-axis and IQ on the Y-axis.
# Create a scatter plot with Shoe_Size on the X-Axis and Study_Hours on the Y-axis.
# Create a histogram of Shoe_Size
# Add a title and axis labels to make the plot clear.
# After you plot it, answer the question: Does there appear to be a correlation?

# %%
df1=pd.read_csv('student_IQdata.csv')
df1.head()
# Out:
#    Shoe_Size  Study_Hour  Chilling_Hours  IQ_Score
# 0       13.5         2.0            17.7        72
# 1        8.0        18.0             5.0        75
# 2        6.4         7.2            22.7        78
# 3        6.9         8.7             6.6       110
# 4       10.5         8.6             5.8       104

# %%
plt.scatter(df1['Study_Hour'], df1['IQ_Score'])
plt.title('Relationship between Study Hours and IQ')
plt.xlabel('Study Hour')
plt.ylabel('IQ Score')
# Out:
# Text(0, 0.5, 'IQ Score')

# %%
# Create a scatter plot with Shoe_Size on the X-Axis and Study_Hours on the Y-axis. 
# fig=px.scatter(df1,x='Shoe_Size',y='Study_Hour',title='Relationship between Shoe Size and Study Hours')
# fig.show() 
import matplotlib.pyplot as plt

plt.scatter(df1['Shoe_Size'], df1['Study_Hour'])
plt.title('Relationship between Shoe Size and Study Hours')
plt.xlabel('Shoe Size')
plt.ylabel('Study Hour')
plt.show()

# %%
# Create a histogram of Shoe_Size
# fig=px.histogram(df1,x='Shoe_Size',title='Distribution of Shoe Sizes',)
# fig.show()

# %%
plt.hist(df1['Shoe_Size'])
plt.title('Distribution of Shoe Sizes')
plt.xlabel('Shoe Size')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
