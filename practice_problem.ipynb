# %% [markdown]
# prothomaakter937@gmail.com

# %% [markdown]
# Question : 1
# Load the TrainingHours column into a NumPy array.
# Convert to float datatype
# Find mean & standard deviation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv('/content/sample_data/final-employee-ds.csv')
df.head()
# Out:
#    EmployeeID        Name  Age  Gender Department  ExperienceYears   Salary  \
# 0         101  Employee_1   50    Male         IT               17  86175.0
# 1         102  Employee_2   36    Male    Finance                1  47805.0
# 2         103  Employee_3   29    Male  Marketing               16  45237.0
# 3         104  Employee_4   42    Male  Marketing               12  60056.0
# 4         105  Employee_5   40  Female    Finance               19  85543.0
#
#    WorkHoursPerWeek  PerformanceScore    JoinDate Tshirt_size  ProjectCount  \
# 0                44                71  2010-01-10           L             2
# 1                44                68  2017-11-11           S             4
# 2                44                69  2012-03-08           S             6
# 3                48                76  2012-10-12           M             2
# 4                36                97  2014-12-30          XL             8
#
#    TrainingHours  DepartmentRating
# ...

# %% [markdown]
# # Question : 1

# %%
arr=np.array(df['TrainingHours'],dtype=np.float64)
arr_m=np.mean(arr)
arr_std=np.std(arr)
print(arr_m)
print(arr_std)
# Out:
# 24.19
# 13.842467265628624

# %% [markdown]
# #Question : 2

# %%
# df['Salary'].isnull().sum()
dept=df.groupby('Department')['Salary']
df['Salary']=df['Salary'].fillna(dept.transform('median'))
# df['Salary'].isnull().sum()
# Calculate total Salary sum for employees with ExperienceYears > 12 and ProjectCount > 5
total_salary=df.loc[(df['ExperienceYears']>12) & (df['ProjectCount']>5),'Salary'].sum()
print(total_salary)
# Out:
# 1985775.5

# %% [markdown]
# # Question : 3

# %%
df[df['Department'].isin(['IT', 'Finance'])].loc[(df['Age'] >= 30) & (df['Age'] <= 45) & (df['PerformanceScore'] > 88)].sort_values(by=['Salary'], ascending=False)[['Name', 'Department', 'Salary', 'PerformanceScore']]
# Out:
#            Name Department    Salary  PerformanceScore
# 94  Employee_95         IT  140386.0                94
# 88  Employee_89    Finance  126027.0                92
# 4    Employee_5    Finance   85543.0                97
# 32  Employee_33         IT   83919.0                98
# 55  Employee_56    Finance   49540.0                94

# %% [markdown]
# # Question : 4

# %%
df['SalaryPerHour'] = df['Salary'] / (df['WorkHoursPerWeek'] * 4)
df.sort_values(by='SalaryPerHour', ascending=False).head(5)[['Name', 'SalaryPerHour']]
# Out:
#            Name  SalaryPerHour
# 46  Employee_47     981.278571
# 27  Employee_28     971.292857
# 31  Employee_32     967.392857
# 79  Employee_80     945.335526
# 80  Employee_81     937.858974

# %% [markdown]
# Question : 5

# %%
sns.countplot(x='Department', hue='Gender', data=df)
plt.show()
